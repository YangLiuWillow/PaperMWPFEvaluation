# %% [markdown]
# # Compare decoders logical error rates
#
# This notebook will evaluate the accuracy of a list of decoders given a list of codes and noises.
# It will use exactly the same sequence of syndrome such that better comparison could be done even with fewer data.
#
# This notebook only provides basic plotting.
#
# To execute this notebook with a custom code, noise and list of decoders, use
# ```sh
# # srun --time=1-00:00:00 --mem=10G --cpus-per-task=2 \
# python3 -m qec_lego_bench notebook-pl-p-compare-decoders ./dist/pl_p_compare_decoders_example.ipynb 'rsc(d=3;p=0.01)' --decoder 'mwpm' --decoder 'mwpf(c=0)' --decoder 'mwpf(c=50)' --target-precision 0.1 --local-maximum-jobs 8
# ```

# %%
codes: list[str] = ["css_rsc(d@3)", "css_rsc(d@3)", "css_rsc(d@5)", "css_rsc(d@5)"]
noises: list[str] = ["depolarize(p@0.05)", "depolarize(p@0.08)", "depolarize(p@0.05)", "depolarize(p@0.08)"]
decoders: list[str] = ["mwpf", "mwpm"]

max_cpu_hours: float = None
min_precision: float = 1
target_precision: float = 0.04  # about 4000 errors for the configuration with the smallest 
high_pL_threshold: float = 0.2  # we do care about high logical error rates since we want to know the threshold

# adaptive min shots submitter
min_shots: int = 1000
max_shots: int = 1000000
max_errors: int = 20  # the submitter terminates when the number of errors exceeds this value
max_adaptive_min_shots_cpu_hours: float = None

slurm_maximum_jobs: int = 50  # start with a smaller number of workers to avoid resource waste
slurm_cores_per_node: int = 10  # (slurm_maximum_jobs // slurm_cores_per_node) should not exceed 200
slurm_mem_per_job: int = 4  # 4GB per job
slurm_extra: dict = dict(
    walltime = "1-00:00:00",  # adaptively shutdown if no more jobs
    queue = "scavenge",  # use with caution: dask does not seem to handle scavenge workers well
    job_extra_directives = ["--requeue"],  # use with scavenge partition will help spawn scavenged jobs
)

import multiprocessing
local_maximum_jobs: int = multiprocessing.cpu_count()

json_filename: str = None
cpu: str = "unknown"
force_finished: bool = False  # only plot the figure and do not run experiments

# %%
# Parameters
codes = ["rsc(d@3;p@0.015)", "rsc(d@5;p@0.015)", "rsc(d@7;p@0.015)", "rsc(d@9;p@0.015)", "rsc(d@11;p@0.015)", "rsc(d@3;p@0.01)", "rsc(d@5;p@0.01)", "rsc(d@7;p@0.01)", "rsc(d@9;p@0.01)", "rsc(d@11;p@0.01)", "rsc(d@3;p@0.007)", "rsc(d@5;p@0.007)", "rsc(d@7;p@0.007)", "rsc(d@9;p@0.007)", "rsc(d@11;p@0.007)", "rsc(d@3;p@0.005)", "rsc(d@5;p@0.005)", "rsc(d@7;p@0.005)", "rsc(d@9;p@0.005)", "rsc(d@11;p@0.005)", "rsc(d@3;p@0.003)", "rsc(d@5;p@0.003)", "rsc(d@7;p@0.003)", "rsc(d@9;p@0.003)", "rsc(d@11;p@0.003)", "rsc(d@3;p@0.002)", "rsc(d@5;p@0.002)", "rsc(d@7;p@0.002)", "rsc(d@9;p@0.002)", "rsc(d@11;p@0.002)", "rsc(d@3;p@0.001)", "rsc(d@5;p@0.001)", "rsc(d@7;p@0.001)", "rsc(d@3;p@0.0005)", "rsc(d@5;p@0.0005)", "rsc(d@3;p@0.0002)", "rsc(d@3;p@0.0001)"]
noises = ["none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none", "none"]
decoders = ["fb(max_tree_size@0)", "fb", "mwpf(c@0)", "mwpf(c@200)"]
json_filename = "circuit-rsc-c200.json"
target_precision = 0.04
high_pL_threshold = 0.1
max_shots = 10000000
slurm_maximum_jobs = 100
local_maximum_jobs = 11

# %%
# %load_ext autoreload
# %autoreload 2

# %%
codes = [code.replace("@", "=").replace(";", ",") for code in codes]
noises = [noise.replace("@", "=").replace(";", ",") for noise in noises]
decoders = [decoder.replace("@", "=").replace(";", ",") for decoder in decoders]

from qec_lego_bench.notebooks.pL_p_compare_decoders import *
from qec_lego_bench.notebooks.compare_decoder import CompareDecoderMonteCarloFunction

codes, noises = sanity_check_parse_codes_and_noises(codes, noises)

if json_filename is None:
    json_filename = default_json_filename()
print("saving results to:", json_filename)

if max_cpu_hours is not None and max_adaptive_min_shots_cpu_hours is None:
    max_adaptive_min_shots_cpu_hours = max_cpu_hours
# Out:
# saving results to: circuit-rsc-c200.json

# %%
jobs = [MonteCarloJob(code=code, noise=noise) for code, noise in zip(codes, noises)]

monte_carlo_function = CompareDecoderMonteCarloFunction(
    decoders=decoders,
)

if not force_finished:
    print(monte_carlo_function(10, code=codes[0], noise=noises[0], verbose=True))
# Out:
# Writing Circuit file to /var/folders/x4/zy4mgv3950q4s06099xx0h2w0000gn/T/tmpqy4214ui/tmp.stim
# Writing DEM file to /var/folders/x4/zy4mgv3950q4s06099xx0h2w0000gn/T/tmpqy4214ui/tmp.dem
# Writing detectors to /var/folders/x4/zy4mgv3950q4s06099xx0h2w0000gn/T/tmpqy4214ui/tmp.det.b8 and observables to /var/folders/x4/zy4mgv3950q4s06099xx0h2w0000gn/T/tmpqy4214ui/tmp.obs.b8
#   0%|                                                                                                   | 0/4 [00:00<?, ?it/s]
#  25%|██████████████████████▊                                                                    | 1/4 [00:00<00:00,  6.30it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 20.13it/s]
# (10, MultiDecoderLogicalErrorRates(results={'fb(max_tree_size=0)': LogicalErrorResult(errors=1, discards=0, panic_cases=None, elapsed=0.0020152090000919998), 'fb': LogicalErrorResult(errors=1, discards=0, panic_cases=None, elapsed=0.0017457080102758482), 'mwpf(c=0)': LogicalErrorResult(errors=1, discards=0, panic_cases=None, elapsed=0.0004797688840578), 'mwpf(c=200)': LogicalErrorResult(errors=1, discards=0, panic_cases=None, elapsed=0.0007792122293418895)}))

# %%
adaptive_min_shots_submitter = AdaptiveMinShotsSubmitter(
    min_shots=min_shots,
    max_shots=max_shots,
    max_errors=max_errors,
    time_limit=max_adaptive_min_shots_cpu_hours * 3600 if max_adaptive_min_shots_cpu_hours is not None else None,
)

precision_submitter = PrecisionSubmitter(
    time_limit=max_cpu_hours * 3600 if max_cpu_hours is not None else None,
    min_precision=min_precision,
    target_precision=target_precision,
    high_pL_threshold=high_pL_threshold,
)

def submitter(executor: MonteCarloJobExecutor) -> list[tuple[MonteCarloJob, int]]:
    submit = adaptive_min_shots_submitter(executor)
    if len(submit) == 0 and executor.no_pending():  # previous submitter all finished
        submit += precision_submitter(executor)
    return submit

# %%
config = MonteCarloExecutorConfig()
config.max_submitted_job = max(config.max_submitted_job, 3 * slurm_maximum_jobs)
executor = MonteCarloJobExecutor(
    monte_carlo_function,
    jobs,
    config=config,
    filename=json_filename,
    result_type=MultiDecoderLogicalErrorRates,
)

client_connector = SlurmClientConnector(
    slurm_maximum_jobs=slurm_maximum_jobs,
    slurm_cores_per_node=slurm_cores_per_node,
    slurm_mem_per_job=slurm_mem_per_job,
    slurm_extra=slurm_extra,
    local_maximum_jobs=local_maximum_jobs,
)

# %%
import time  # add some sleep to let them work properly in VScode Jupyter notebook

time.sleep(0.2)
progress_plotter = JobProgressPlotter()
time.sleep(0.2)
compare_decoder_plotter = PlPCompareDecodersPlotter(
    decoders = decoders, codes=codes, noises=noises
)
time.sleep(0.2)
memory_plotter = MemoryUsagePlotter()


def callback(executor: MonteCarloJobExecutor):
    progress_plotter(executor)
    time.sleep(0.1)
    compare_decoder_plotter(executor)
    time.sleep(0.1)
    memory_plotter(executor)
    time.sleep(0.1)


executor.execute(
    client_connector=client_connector,
    submitter=submitter,
    loop_callback=callback,
    shutdown_cluster=True,
    force_finished=force_finished,
)
# Out:
# <style type="text/css">
# #T_026e3 th {
#   text-align: center;
# }
# #T_026e3_row0_col0, #T_026e3_row0_col2, #T_026e3_row1_col0, #T_026e3_row1_col2, #T_026e3_row2_col0, #T_026e3_row2_col2, #T_026e3_row3_col0, #T_026e3_row3_col2, #T_026e3_row4_col0, #T_026e3_row4_col2, #T_026e3_row5_col0, #T_026e3_row5_col2, #T_026e3_row6_col0, #T_026e3_row6_col2, #T_026e3_row7_col0, #T_026e3_row7_col2, #T_026e3_row8_col0, #T_026e3_row8_col2, #T_026e3_row9_col0, #T_026e3_row9_col2, #T_026e3_row10_col0, #T_026e3_row10_col2, #T_026e3_row11_col0, #T_026e3_row11_col2, #T_026e3_row12_col0, #T_026e3_row12_col2, #T_026e3_row13_col0, #T_026e3_row13_col2, #T_026e3_row14_col0, #T_026e3_row14_col2, #T_026e3_row15_col0, #T_026e3_row15_col2, #T_026e3_row16_col0, #T_026e3_row16_col2, #T_026e3_row17_col0, #T_026e3_row17_col2, #T_026e3_row18_col0, #T_026e3_row18_col2, #T_026e3_row19_col0, #T_026e3_row19_col2, #T_026e3_row20_col0, #T_026e3_row20_col2, #T_026e3_row21_col0, #T_026e3_row21_col2, #T_026e3_row22_col0, #T_026e3_row22_col2, #T_026e3_row23_col0, #T_026e3_row23_col2, #T_026e3_row24_col0, #T_026e3_row24_col2, #T_026e3_row25_col0, #T_026e3_row25_col2, #T_026e3_row26_col0, #T_026e3_row26_col2, #T_026e3_row27_col0, #T_026e3_row27_col2, #T_026e3_row28_col0, #T_026e3_row28_col2, #T_026e3_row29_col0, #T_026e3_row29_col2, #T_026e3_row30_col0, #T_026e3_row30_col2, #T_026e3_row31_col0, #T_026e3_row31_col2, #T_026e3_row32_col0, #T_026e3_row32_col2, #T_026e3_row33_col0, #T_026e3_row33_col2, #T_026e3_row34_col0, #T_026e3_row34_col2, #T_026e3_row35_col0, #T_026e3_row35_col2, #T_026e3_row36_col0, #T_026e3_row36_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_026e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_026e3_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_026e3_level0_col1" class="col_heading level0 col1" >JobKey</th>
#       <th id="T_026e3_level0_col2" class="col_heading level0 col2" >Job</th>
#       <th id="T_026e3_level0_col3" class="col_heading level0 col3" >Finished</th>
#       <th id="T_026e3_level0_col4" class="col_heading level0 col4" >Pending</th>
#       <th id="T_026e3_level0_col5" class="col_heading level0 col5" >Submitted</th>
#       <th id="T_026e3_level0_col6" class="col_heading level0 col6" >72 jobs</th>
#       <th id="T_026e3_level0_col7" class="col_heading level0 col7" >Total</th>
#       <th id="T_026e3_level0_col8" class="col_heading level0 col8" >Duration</th>
#       <th id="T_026e3_level0_col9" class="col_heading level0 col9" >Errors</th>
#       <th id="T_026e3_level0_col10" class="col_heading level0 col10" >Discards</th>
#       <th id="T_026e3_level0_col11" class="col_heading level0 col11" >Panics</th>
#       <th id="T_026e3_level0_col12" class="col_heading level0 col12" >Error Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_026e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_026e3_row0_col0" class="data row0 col0" >pending</td>
#       <td id="T_026e3_row0_col1" class="data row0 col1" >7fe341</td>
#       <td id="T_026e3_row0_col2" class="data row0 col2" >Job(code=rsc(d=11,p=0.003), noise=none)</td>
#       <td id="T_026e3_row0_col3" class="data row0 col3" >826 (50%)</td>
#       <td id="T_026e3_row0_col4" class="data row0 col4" >826 (50%)</td>
#       <td id="T_026e3_row0_col5" class="data row0 col5" >826 (50%)</td>
#       <td id="T_026e3_row0_col6" class="data row0 col6" >10 (13%)</td>
#       <td id="T_026e3_row0_col7" class="data row0 col7" >1652</td>
#       <td id="T_026e3_row0_col8" class="data row0 col8" >1632.4s (27.2min)</td>
#       <td id="T_026e3_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_026e3_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_026e3_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_026e3_row0_col12" class="data row0 col12" >0.0(0)</td>
#     </tr>
#     <tr>
#       <th id="T_026e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_026e3_row1_col0" class="data row1 col0" >pending</td>
#       <td id="T_026e3_row1_col1" class="data row1 col1" >ded871</td>
#       <td id="T_026e3_row1_col2" class="data row1 col2" >Job(code=rsc(d=7,p=0.005), noise=none)</td>
#       <td id="T_026e3_row1_col3" class="data row1 col3" >1000 (50%)</td>
#       <td id="T_026e3_row1_col4" class="data row1 col4" >1000 (50%)</td>
#       <td id="T_026e3_row1_col5" class="data row1 col5" >1000 (50%)</td>
#       <td id="T_026e3_row1_col6" class="data row1 col6" >7 (9%)</td>
#       <td id="T_026e3_row1_col7" class="data row1 col7" >2000</td>
#       <td id="T_026e3_row1_col8" class="data row1 col8" >1163.0s (19.4min)</td>
#       <td id="T_026e3_row1_col9" class="data row1 col9" >8</td>
#       <td id="T_026e3_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_026e3_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_026e3_row1_col12" class="data row1 col12" >0.008(7)</td>
#     </tr>
#     <tr>
#       <th id="T_026e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_026e3_row2_col0" class="data row2 col0" >pending</td>
#       <td id="T_026e3_row2_col1" class="data row2 col1" >39fd4a</td>
#       <td id="T_026e3_row2_col2" class="data row2 col2" >Job(code=rsc(d=9,p=0.003), noise=none)</td>
#       <td id="T_026e3_row2_col3" class="data row2 col3" >1000 (50%)</td>
#       <td id="T_026e3_row2_col4" class="data row2 col4" >1000 (50%)</td>
#       <td id="T_026e3_row2_col5" class="data row2 col5" >1000 (50%)</td>
#       <td id="T_026e3_row2_col6" class="data row2 col6" >6 (8%)</td>
#       <td id="T_026e3_row2_col7" class="data row2 col7" >2000</td>
#       <td id="T_026e3_row2_col8" class="data row2 col8" >895.7s (14.9min)</td>
#       <td id="T_026e3_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_026e3_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_026e3_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_026e3_row2_col12" class="data row2 col12" >0.0(0)</td>
#     </tr>
#     <tr>
#       <th id="T_026e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_026e3_row3_col0" class="data row3 col0" >pending</td>
#       <td id="T_026e3_row3_col1" class="data row3 col1" >cfa91d</td>
#       <td id="T_026e3_row3_col2" class="data row3 col2" >Job(code=rsc(d=9,p=0.002), noise=none)</td>
#       <td id="T_026e3_row3_col3" class="data row3 col3" >2768 (50%)</td>
#       <td id="T_026e3_row3_col4" class="data row3 col4" >2768 (50%)</td>
#       <td id="T_026e3_row3_col5" class="data row3 col5" >2768 (50%)</td>
#       <td id="T_026e3_row3_col6" class="data row3 col6" >4 (5%)</td>
#       <td id="T_026e3_row3_col7" class="data row3 col7" >5536</td>
#       <td id="T_026e3_row3_col8" class="data row3 col8" >597.4s (10.0min)</td>
#       <td id="T_026e3_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_026e3_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_026e3_row3_col11" class="data row3 col11" >0</td>
#       <td id="T_026e3_row3_col12" class="data row3 col12" >0.0(0)</td>
#     </tr>
#     <tr>
#       <th id="T_026e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_026e3_row4_col0" class="data row4 col0" >pending</td>
#       <td id="T_026e3_row4_col1" class="data row4 col1" >fac0c6</td>
#       <td id="T_026e3_row4_col2" class="data row4 col2" >Job(code=rsc(d=11,p=0.01), noise=none)</td>
#       <td id="T_026e3_row4_col3" class="data row4 col3" >16 (1%)</td>
#       <td id="T_026e3_row4_col4" class="data row4 col4" >984 (98%)</td>
#       <td id="T_026e3_row4_col5" class="data row4 col5" >16 (1%)</td>
#       <td id="T_026e3_row4_col6" class="data row4 col6" >1 (1%)</td>
#       <td id="T_026e3_row4_col7" class="data row4 col7" >1000</td>
#       <td id="T_026e3_row4_col8" class="data row4 col8" >559.8s (9.3min)</td>
#       <td id="T_026e3_row4_col9" class="data row4 col9" >1</td>
#       <td id="T_026e3_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_026e3_row4_col11" class="data row4 col11" >0</td>
#       <td id="T_026e3_row4_col12" class="data row4 col12" >0.1(2)</td>
#     </tr>
#     <tr>
#       <th id="T_026e
# winding up a new client
# No module named 'dask_jobqueue'
# cluster dashboard link: http://127.0.0.1:8787/status
# 2025-06-06 00:27:29,679 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-b561bcfaa93f6f8e4eead0a94973d998')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,680 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-f0a2b1d7e23d4b573ab8fa86c42347f4')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,682 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-c283289dcee90ae7252fcf39b57f7fdc')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,683 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-58670964b12c89bf25c275a4f12eb66c')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,683 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-cbbac24ea6c947356a4d38a502b50309')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,683 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-2039274c0306a7d5c5aa1fb1ec610f34')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,687 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-34bcf6f3f0c3df626f37960d559d4cf9')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,689 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-1fc0d014905d75ea82f1f7e509986ca1')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,689 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-47820985a79de95f6f91ce61fca96fe5')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,690 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-7a70e67966e590b3e1ce2e3e2b1ad496')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-06-06 00:27:29,691 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-048f3fe58e3b474a5b4fec5760750a7c')" coro=<Worker.execute() done, defined at /Users/wuyue/miniconda3/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# shutting down the cluster; if this is not desired, set `shutdown_cluster` to `False`
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 22
#      18     memory_plotter(executor)
#      19     time.sleep(0.1)
# ---> 22 executor.execute(
#      23     client_connector=client_connector,
#      24     submitter=submitter,
#      25     loop_callback=callback,
#      26     shutdown_cluster=True,
#      27     force_finished=force_finished,
#      28 )
#
# File ~/Documents/GitHub/qec-lego-bench/src/qec_lego_bench/hpc/monte_carlo.py:427, in MonteCarloJobExecutor.execute(self, client, submitter, timeout, loop_callback, force_finished, client_connector, shutdown_cluster)
#     425     raise TimeoutError()
#     426 try:
# --> 427     futures: DoneAndNotDoneFutures = wait(
#     428         self.pending_futures,
#     429         return_when=FIRST_COMPLETED,
#     430         timeout=timeout - (time.time() - start),
#     431     )
#     432 except DaskTimeoutError as e:
#     433     raise TimeoutError()
#
# File ~/miniconda3/lib/python3.12/site-packages/distributed/client.py:5714, in wait(fs, timeout, return_when)
#    5712     timeout = parse_timedelta(timeout, default="s")
#    5713 client = default_client()
# -> 5714 result = client.sync(_wait, fs, timeout=timeout, return_when=return_when)
#    5715 return result
#
# File ~/miniconda3/lib/python3.12/site-packages/distributed/utils.py:363, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     361     return future
#     362 else:
# --> 363     return sync(
#     364         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     365     )
#
# File ~/miniconda3/lib/python3.12/site-packages/distributed/utils.py:436, in sync(loop, func, callback_timeout, *args, **kwargs)
#     434 else:
#     435     while not e.is_set():
# --> 436         wait(10)
#     438 if error is not None:
#     439     raise error
#
# File ~/miniconda3/lib/python3.12/site-packages/distributed/utils.py:425, in sync.<locals>.wait(timeout)
#     423 def wait(timeout: float | None) -> bool:
#     424     try:
# --> 425         return e.wait(timeout)
#     426     except KeyboardInterrupt:
#     427         loop.add_callback(cancel)
#
# File ~/miniconda3/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
