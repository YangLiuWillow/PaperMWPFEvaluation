# %% [markdown]
# # Compare decoders logical error rates
#
# This notebook will evaluate the accuracy of a list of decoders given a list of codes and noises.
# It will use exactly the same sequence of syndrome such that better comparison could be done even with fewer data.
#
# This notebook only provides basic plotting.
#
# To execute this notebook with a custom code, noise and list of decoders, use
# ```sh
# # srun --time=1-00:00:00 --mem=10G --cpus-per-task=2 \
# python3 -m qec_lego_bench notebook-pl-p-compare-decoders ./dist/pl_p_compare_decoders_example.ipynb 'rsc(d=3;p=0.01)' --decoder 'mwpm' --decoder 'mwpf(c=0)' --decoder 'mwpf(c=50)' --target-precision 0.1 --local-maximum-jobs 8
# ```

# %%
codes: list[str] = ["css_rsc(d@3)", "css_rsc(d@3)", "css_rsc(d@5)", "css_rsc(d@5)"]
noises: list[str] = ["depolarize(p@0.05)", "depolarize(p@0.08)", "depolarize(p@0.05)", "depolarize(p@0.08)"]
decoders: list[str] = ["mwpf", "mwpm"]

max_cpu_hours: float = None
min_precision: float = 1
target_precision: float = 0.04  # about 4000 errors for the configuration with the smallest 
high_pL_threshold: float = 0.2  # we do care about high logical error rates since we want to know the threshold

# adaptive min shots submitter
min_shots: int = 1000
max_shots: int = 1000000
max_errors: int = 20  # the submitter terminates when the number of errors exceeds this value
max_adaptive_min_shots_cpu_hours: float = None

slurm_maximum_jobs: int = 50  # start with a smaller number of workers to avoid resource waste
slurm_cores_per_node: int = 10  # (slurm_maximum_jobs // slurm_cores_per_node) should not exceed 200
slurm_mem_per_job: int = 4  # 4GB per job
slurm_extra: dict = dict(
    walltime = "1-00:00:00",  # adaptively shutdown if no more jobs
    queue = "scavenge",  # use with caution: dask does not seem to handle scavenge workers well
    job_extra_directives = ["--requeue"],  # use with scavenge partition will help spawn scavenged jobs
)

import multiprocessing
local_maximum_jobs: int = multiprocessing.cpu_count()

json_filename: str = None
cpu: str = "unknown"
force_finished: bool = False  # only plot the figure and do not run experiments

# %%
# Parameters
codes = [
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@144;k@12;d@12)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@90;k@8;d@10)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
    "bb(n@72;k@12;d@6)",
]
noises = [
    "depolarize(p@0.4)",
    "depolarize(p@0.4)",
    "depolarize(p@0.4)",
    "depolarize(p@0.3)",
    "depolarize(p@0.3)",
    "depolarize(p@0.3)",
    "depolarize(p@0.2)",
    "depolarize(p@0.2)",
    "depolarize(p@0.2)",
    "depolarize(p@0.1)",
    "depolarize(p@0.1)",
    "depolarize(p@0.1)",
    "depolarize(p@0.05)",
    "depolarize(p@0.05)",
    "depolarize(p@0.05)",
    "depolarize(p@0.04)",
    "depolarize(p@0.04)",
    "depolarize(p@0.04)",
    "depolarize(p@0.03)",
    "depolarize(p@0.03)",
    "depolarize(p@0.03)",
    "depolarize(p@0.025)",
    "depolarize(p@0.025)",
    "depolarize(p@0.025)",
    "depolarize(p@0.02)",
    "depolarize(p@0.02)",
    "depolarize(p@0.02)",
    "depolarize(p@0.018)",
    "depolarize(p@0.018)",
    "depolarize(p@0.015)",
    "depolarize(p@0.015)",
    "depolarize(p@0.0125)",
    "depolarize(p@0.0125)",
    "depolarize(p@0.01)",
    "depolarize(p@0.01)",
    "depolarize(p@0.0078)",
    "depolarize(p@0.00625)",
    "depolarize(p@0.005)",
    "depolarize(p@0.005)",
    "depolarize(p@0.004)",
    "depolarize(p@0.003)",
    "depolarize(p@0.0025)",
    "depolarize(p@0.002)",
    "depolarize(p@0.0018)",
    "depolarize(p@0.0015)",
    "depolarize(p@0.00125)",
    "depolarize(p@0.001)",
]
decoders = ["bposd(max_iter@1000;ms_scaling_factor@1)"]
json_filename = "capacity-bb-bposd0-iter1000.json"
target_precision = 0.04
max_shots = 10000000
local_maximum_jobs = 9

# %%
# %load_ext autoreload
# %autoreload 2

# %%
codes = [code.replace("@", "=").replace(";", ",") for code in codes]
noises = [noise.replace("@", "=").replace(";", ",") for noise in noises]
decoders = [decoder.replace("@", "=").replace(";", ",") for decoder in decoders]

from qec_lego_bench.notebooks.pL_p_compare_decoders import *
from qec_lego_bench.notebooks.compare_decoder import CompareDecoderMonteCarloFunction

codes, noises = sanity_check_parse_codes_and_noises(codes, noises)

if json_filename is None:
    json_filename = default_json_filename()
print("saving results to:", json_filename)

if max_cpu_hours is not None and max_adaptive_min_shots_cpu_hours is None:
    max_adaptive_min_shots_cpu_hours = max_cpu_hours
# Out:
# saving results to: capacity-bb-bposd0-iter1000.json

# %%
jobs = [MonteCarloJob(code=code, noise=noise) for code, noise in zip(codes, noises)]

monte_carlo_function = CompareDecoderMonteCarloFunction(
    decoders=decoders,
)

if not force_finished:
    print(monte_carlo_function(10, code=codes[0], noise=noises[0], verbose=True))
# Out:
# Writing Circuit file to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmp9wxzzxrb/tmp.stim
# Writing DEM file to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmp9wxzzxrb/tmp.dem
# Writing detectors to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmp9wxzzxrb/tmp.det.b8 and observables to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmp9wxzzxrb/tmp.obs.b8
#   0%|                                                                                                                                                                                                                                                                                                         | 0/1 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.11it/s]
# (10, MultiDecoderLogicalErrorRates(results={'bposd(max_iter=1000,ms_scaling_factor=1)': LogicalErrorResult(errors=10, discards=0, panic_cases=None, elapsed=0.04934342555417162)}))

# %%
adaptive_min_shots_submitter = AdaptiveMinShotsSubmitter(
    min_shots=min_shots,
    max_shots=max_shots,
    max_errors=max_errors,
    time_limit=max_adaptive_min_shots_cpu_hours * 3600 if max_adaptive_min_shots_cpu_hours is not None else None,
)

precision_submitter = PrecisionSubmitter(
    time_limit=max_cpu_hours * 3600 if max_cpu_hours is not None else None,
    min_precision=min_precision,
    target_precision=target_precision,
    high_pL_threshold=high_pL_threshold,
)

def submitter(executor: MonteCarloJobExecutor) -> list[tuple[MonteCarloJob, int]]:
    submit = adaptive_min_shots_submitter(executor)
    if len(submit) == 0 and executor.no_pending():  # previous submitter all finished
        submit += precision_submitter(executor)
    return submit

# %%
config = MonteCarloExecutorConfig()
config.max_submitted_job = max(config.max_submitted_job, 3 * slurm_maximum_jobs)
executor = MonteCarloJobExecutor(
    monte_carlo_function,
    jobs,
    config=config,
    filename=json_filename,
    result_type=MultiDecoderLogicalErrorRates,
)

client_connector = SlurmClientConnector(
    slurm_maximum_jobs=slurm_maximum_jobs,
    slurm_cores_per_node=slurm_cores_per_node,
    slurm_mem_per_job=slurm_mem_per_job,
    slurm_extra=slurm_extra,
    local_maximum_jobs=local_maximum_jobs,
)

# %%
import time  # add some sleep to let them work properly in VScode Jupyter notebook

time.sleep(0.2)
progress_plotter = JobProgressPlotter()
time.sleep(0.2)
compare_decoder_plotter = PlPCompareDecodersPlotter(
    decoders = decoders, codes=codes, noises=noises
)
time.sleep(0.2)
memory_plotter = MemoryUsagePlotter()


def callback(executor: MonteCarloJobExecutor):
    progress_plotter(executor)
    time.sleep(0.1)
    compare_decoder_plotter(executor)
    time.sleep(0.1)
    memory_plotter(executor)
    time.sleep(0.1)


executor.execute(
    client_connector=client_connector,
    submitter=submitter,
    loop_callback=callback,
    shutdown_cluster=True,
    force_finished=force_finished,
)
# Out:
# <style type="text/css">
# #T_bc028 th {
#   text-align: center;
# }
# #T_bc028_row0_col0, #T_bc028_row0_col2, #T_bc028_row1_col0, #T_bc028_row1_col2, #T_bc028_row2_col0, #T_bc028_row2_col2, #T_bc028_row3_col0, #T_bc028_row3_col2, #T_bc028_row4_col0, #T_bc028_row4_col2, #T_bc028_row5_col0, #T_bc028_row5_col2, #T_bc028_row6_col0, #T_bc028_row6_col2, #T_bc028_row7_col0, #T_bc028_row7_col2, #T_bc028_row8_col0, #T_bc028_row8_col2, #T_bc028_row9_col0, #T_bc028_row9_col2, #T_bc028_row10_col0, #T_bc028_row10_col2, #T_bc028_row11_col0, #T_bc028_row11_col2, #T_bc028_row12_col0, #T_bc028_row12_col2, #T_bc028_row13_col0, #T_bc028_row13_col2, #T_bc028_row14_col0, #T_bc028_row14_col2, #T_bc028_row15_col0, #T_bc028_row15_col2, #T_bc028_row16_col0, #T_bc028_row16_col2, #T_bc028_row17_col0, #T_bc028_row17_col2, #T_bc028_row18_col0, #T_bc028_row18_col2, #T_bc028_row19_col0, #T_bc028_row19_col2, #T_bc028_row20_col0, #T_bc028_row20_col2, #T_bc028_row21_col0, #T_bc028_row21_col2, #T_bc028_row22_col0, #T_bc028_row22_col2, #T_bc028_row23_col0, #T_bc028_row23_col2, #T_bc028_row24_col0, #T_bc028_row24_col2, #T_bc028_row25_col0, #T_bc028_row25_col2, #T_bc028_row26_col0, #T_bc028_row26_col2, #T_bc028_row27_col0, #T_bc028_row27_col2, #T_bc028_row28_col0, #T_bc028_row28_col2, #T_bc028_row29_col0, #T_bc028_row29_col2, #T_bc028_row30_col0, #T_bc028_row30_col2, #T_bc028_row31_col0, #T_bc028_row31_col2, #T_bc028_row32_col0, #T_bc028_row32_col2, #T_bc028_row33_col0, #T_bc028_row33_col2, #T_bc028_row34_col0, #T_bc028_row34_col2, #T_bc028_row35_col0, #T_bc028_row35_col2, #T_bc028_row36_col0, #T_bc028_row36_col2, #T_bc028_row37_col0, #T_bc028_row37_col2, #T_bc028_row38_col0, #T_bc028_row38_col2, #T_bc028_row39_col0, #T_bc028_row39_col2, #T_bc028_row40_col0, #T_bc028_row40_col2, #T_bc028_row41_col0, #T_bc028_row41_col2, #T_bc028_row42_col0, #T_bc028_row42_col2, #T_bc028_row43_col0, #T_bc028_row43_col2, #T_bc028_row44_col0, #T_bc028_row44_col2, #T_bc028_row45_col0, #T_bc028_row45_col2, #T_bc028_row46_col0, #T_bc028_row46_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_bc028">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc028_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_bc028_level0_col1" class="col_heading level0 col1" >JobKey</th>
#       <th id="T_bc028_level0_col2" class="col_heading level0 col2" >Job</th>
#       <th id="T_bc028_level0_col3" class="col_heading level0 col3" >Finished</th>
#       <th id="T_bc028_level0_col4" class="col_heading level0 col4" >Pending</th>
#       <th id="T_bc028_level0_col5" class="col_heading level0 col5" >Submitted</th>
#       <th id="T_bc028_level0_col6" class="col_heading level0 col6" >1007 jobs</th>
#       <th id="T_bc028_level0_col7" class="col_heading level0 col7" >Total</th>
#       <th id="T_bc028_level0_col8" class="col_heading level0 col8" >Duration</th>
#       <th id="T_bc028_level0_col9" class="col_heading level0 col9" >Errors</th>
#       <th id="T_bc028_level0_col10" class="col_heading level0 col10" >Discards</th>
#       <th id="T_bc028_level0_col11" class="col_heading level0 col11" >Panics</th>
#       <th id="T_bc028_level0_col12" class="col_heading level0 col12" >Error Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc028_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc028_row0_col0" class="data row0 col0" >pending</td>
#       <td id="T_bc028_row0_col1" class="data row0 col1" >2702ba</td>
#       <td id="T_bc028_row0_col2" class="data row0 col2" >Job(code=bb(n=144,k=12,d=12), noise=depolarize(p=0.02))</td>
#       <td id="T_bc028_row0_col3" class="data row0 col3" >6049834 (1%)</td>
#       <td id="T_bc028_row0_col4" class="data row0 col4" >526558166 (98%)</td>
#       <td id="T_bc028_row0_col5" class="data row0 col5" >199285288 (37%)</td>
#       <td id="T_bc028_row0_col6" class="data row0 col6" >204 (20%)</td>
#       <td id="T_bc028_row0_col7" class="data row0 col7" >532608000</td>
#       <td id="T_bc028_row0_col8" class="data row0 col8" >1143.3s (19.1min)</td>
#       <td id="T_bc028_row0_col9" class="data row0 col9" >46</td>
#       <td id="T_bc028_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_bc028_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_bc028_row0_col12" class="data row0 col12" >8(3)e-06</td>
#     </tr>
#     <tr>
#       <th id="T_bc028_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc028_row1_col0" class="data row1 col0" >pending</td>
#       <td id="T_bc028_row1_col1" class="data row1 col1" >a92290</td>
#       <td id="T_bc028_row1_col2" class="data row1 col2" >Job(code=bb(n=90,k=8,d=10), noise=depolarize(p=0.0125))</td>
#       <td id="T_bc028_row1_col3" class="data row1 col3" >12790149 (0%)</td>
#       <td id="T_bc028_row1_col4" class="data row1 col4" >1587594467 (99%)</td>
#       <td id="T_bc028_row1_col5" class="data row1 col5" >571980545 (35%)</td>
#       <td id="T_bc028_row1_col6" class="data row1 col6" >205 (20%)</td>
#       <td id="T_bc028_row1_col7" class="data row1 col7" >1600384616</td>
#       <td id="T_bc028_row1_col8" class="data row1 col8" >855.6s (14.3min)</td>
#       <td id="T_bc028_row1_col9" class="data row1 col9" >31</td>
#       <td id="T_bc028_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_bc028_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_bc028_row1_col12" class="data row1 col12" >2(1)e-06</td>
#     </tr>
#     <tr>
#       <th id="T_bc028_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc028_row2_col0" class="data row2 col0" >pending</td>
#       <td id="T_bc028_row2_col1" class="data row2 col1" >c75b17</td>
#       <td id="T_bc028_row2_col2" class="data row2 col2" >Job(code=bb(n=144,k=12,d=12), noise=depolarize(p=0.025))</td>
#       <td id="T_bc028_row2_col3" class="data row2 col3" >3785354 (1%)</td>
#       <td id="T_bc028_row2_col4" class="data row2 col4" >300562075 (98%)</td>
#       <td id="T_bc028_row2_col5" class="data row2 col5" >177210083 (58%)</td>
#       <td id="T_bc028_row2_col6" class="data row2 col6" >204 (20%)</td>
#       <td id="T_bc028_row2_col7" class="data row2 col7" >304347429</td>
#       <td id="T_bc028_row2_col8" class="data row2 col8" >813.6s (13.6min)</td>
#       <td id="T_bc028_row2_col9" class="data row2 col9" >45</td>
#       <td id="T_bc028_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_bc028_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_bc028_row2_col12" class="data row2 col12" >1.2(5)e-05</td>
#     </tr>
#     <tr>
#       <th id="T_bc028_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc028_row3_col0" class="data row3 col0" >pending</td>
#       <td id="T_bc028_row3_col1" class="data row3 col1" >f75450</td>
#       <td id="T_bc028_row3_col2" class="data row3 col2" >Job(code=bb(n=90,k=8,d=10), noise=depolarize(p=0.01))</td>
#       <td id="T_bc028_row3_col3" class="data row3 col3" >10000000 (0%)</td>
#       <td id="T_bc028_row3_col4" class="data row3 col4" >3457500000 (99%)</td>
#       <td id="T_bc028_row3_col5" class="data row3 col5" >638212514 (18%)</td>
#       <td id="T_bc028_row3_col6" class="data row3 col6" >206 (20%)</td>
#       <td id="T_bc028_row3_col7" class="data row3 col7" >3467500000</td>
#       <td id="T_bc028_row3_col8" class="data row3 col8" >591.3s (9.9min)</td>
#       <td id="T_bc028_row3_col9" class="data row3 col9" >12</td>
#       <td id="T_bc028_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_bc028_row3_col11" class="data row3 col11" >0</td>
#       <td id="T_bc028_row3_col12" class="data row3 col12" >1.2(9)e-06</td>
#     </tr>
#     <tr>
#       <th id="T_bc028_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc028_row4_col0" class="data row4 col0" >pending</td>
#       <td id="T_bc028_row4_col1" class="data row4 col1" >bb71b6</td>
#       <td id="T_bc028_row4_col2" class="data row4 col2" >Job(code=bb(n=72,k=12,d=6), noise=depolarize(p=0.002))</td>
#       <td id="T_bc028_row4_col3" class="data row4 col3" >1046854 (4%)</td>
#       <td id="T_bc028_row4_col4" class="data row4 col4
# winding up a new client
# No module named 'dask_jobqueue'
# cluster dashboard link: http://127.0.0.1:8787/status
# 2025-05-12 22:27:47,532 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-ae2e47791466e61ea6e40a837a2219f1')" coro=<Worker.execute() done, defined at /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-05-12 22:27:47,533 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-87b2171f0ce19e1c6f7c13c5350e08c4')" coro=<Worker.execute() done, defined at /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-05-12 22:27:47,533 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-33043ab8dd34d8cca4fa90c80eac0b74')" coro=<Worker.execute() done, defined at /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-05-12 22:27:47,545 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-e40ca3abf37c1851b2668f576c703d0b')" coro=<Worker.execute() done, defined at /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-05-12 22:27:47,558 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('monitored_job-e0e798d16d56445feb79021357f7e0b5')" coro=<Worker.execute() done, defined at /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-05-12 22:27:47,612 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:49172' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'monitored_job-62266fc50af8aa5e327b80b09e8f2f1b'} (stimulus_id='handle-worker-cleanup-1747103267.6120052')
# 2025-05-12 22:27:47,620 - distributed.nanny - WARNING - Restarting worker
# 2025-05-12 22:27:47,661 - distributed.nanny - WARNING - Restarting worker
# 2025-05-12 22:27:47,663 - distributed.nanny - WARNING - Restarting worker
# 2025-05-12 22:27:47,783 - distributed.nanny - WARNING - Restarting worker
# 2025-05-12 22:27:47,785 - distributed.nanny - WARNING - Restarting worker
