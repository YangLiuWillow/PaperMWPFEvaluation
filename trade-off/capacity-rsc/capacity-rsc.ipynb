# %% [markdown]
# # Compare decoders programmatically
#
# This notebook will evaluate the accuracy and speed of a list of decoders given a specific code and noise.
# It will use exactly the same sequence of syndrome such that better comparison could be done even with fewer data.
#
# This notebook only provides basic plotting.
# It considers the `none` decoder as splitter and draw multiple lines assuming the parameters in each chunk are continuous.
# It will use the label of the last decoder for each chunk as the curve (but marking the changing suffix of the text as grey).
#
# To execute this notebook with a custom code, noise and list of decoders, use
# ```sh
# # srun --time=1-00:00:00 --mem=10G --cpus-per-task=2 \
# python3 -m qec_lego_bench notebook-compare-decoder compare_decoder_example.ipynb 'rsc(d=3,p=0.01)' --decoder 'mwpf(c=0)' --decoder 'mwpf(c=50)' --decoder none --decoder 'bposd(max_iter=1)' --decoder 'bposd(max_iter=5)' --target-precision 0.1 --local-maximum-jobs 8
# ```

# %%
code: str = "rsc(d@3,p@0.01)"
noise: str = "none"
decoders: list[str] = ["mwpf"]

max_cpu_hours: float = None
target_precision: float = 0.04  # about 4000 errors for the configuration with the smallest 

slurm_maximum_jobs: int = 50  # start with a smaller number of workers to avoid resource waste
slurm_cores_per_node: int = 10  # (slurm_maximum_jobs // slurm_cores_per_node) should not exceed 200
slurm_mem_per_job: int = 4  # 4GB per job
slurm_extra: dict = dict(
    walltime = "1-00:00:00",  # adaptively shutdown if no more jobs
    queue = "scavenge",  # use with caution: dask does not seem to handle scavenge workers well
    job_extra_directives = ["--requeue"],  # use with scavenge partition will help spawn scavenged jobs
)

import multiprocessing
local_maximum_jobs: int = multiprocessing.cpu_count()

json_filename: str = None
cpu: str = "unknown"
force_finished: bool = False  # only plot the figure and do not run experiments

# %%
# Parameters
code = "css_rsc(d@7)"
noise = "depolarize(p@0.01)"
decoders = [
    "fb(max_tree_size@0)",
    "fb(max_tree_size@1)",
    "fb(max_tree_size@2)",
    "fb(max_tree_size@3)",
    "fb(max_tree_size@4)",
    "fb(max_tree_size@5)",
    "fb(max_tree_size@6)",
    "fb(max_tree_size@7)",
    "fb(max_tree_size@8)",
    "fb(max_tree_size@9)",
    "fb(max_tree_size@10)",
    "fb(max_tree_size@15)",
    "fb(max_tree_size@20)",
    "fb(max_tree_size@25)",
    "fb(max_tree_size@30)",
    "fb(max_tree_size@35)",
    "fb(max_tree_size@40)",
    "fb(max_tree_size@45)",
    "fb(max_tree_size@50)",
    "fb(max_tree_size@100)",
    "fb(max_tree_size@150)",
    "fb(max_tree_size@200)",
    "fb(max_tree_size@300)",
    "fb(max_tree_size@500)",
    "fb(max_tree_size@1000)",
    "fb",
    "none",
    "mwpf(c@0)",
    "mwpf(c@1)",
    "mwpf(c@2)",
    "mwpf(c@3)",
    "mwpf(c@4)",
    "mwpf(c@5)",
    "mwpf(c@6)",
    "mwpf(c@7)",
    "mwpf(c@8)",
    "mwpf(c@9)",
    "mwpf(c@10)",
    "mwpf(c@15)",
    "mwpf(c@20)",
    "mwpf(c@25)",
    "mwpf(c@30)",
    "mwpf(c@35)",
    "mwpf(c@40)",
    "mwpf(c@45)",
    "mwpf(c@50)",
    "mwpf(c@100)",
    "mwpf(c@150)",
    "mwpf(c@200)",
    "mwpf(c@300)",
    "mwpf(c@500)",
    "mwpf(c@1000)",
]
json_filename = "capacity-rsc.css-rsc-d-7.depolarize-p-0-01.json"
target_precision = 0.04
local_maximum_jobs = 6

# %%
# %load_ext autoreload
# %autoreload 2

# %%
code = code.replace("@", "=")
noise = noise.replace("@", "=")
decoders = [decoder.replace("@", "=") for decoder in decoders]

from qec_lego_bench.notebooks.compare_decoder import *

if json_filename is None:
    json_filename = default_json_filename(code=code, noise=noise)
print("saving results to:", json_filename)
# Out:
# saving results to: capacity-rsc.css-rsc-d-7.depolarize-p-0-01.json

# %% [markdown]
# ### Define the Monte Carlo job function

# %%
jobs = [MonteCarloJob(code=code, noise=noise)]

monte_carlo_function = CompareDecoderMonteCarloFunction(
    decoders=decoders,
)

if not force_finished:
    print(monte_carlo_function(10, code=code, noise=noise, verbose=True))
# Out:
# Writing Circuit file to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmpnmby18kh/tmp.stim
# Writing DEM file to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmpnmby18kh/tmp.dem
# Writing detectors to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmpnmby18kh/tmp.det.b8 and observables to /var/folders/vt/khhqppkd1472wb_cdm06rqhr0000gn/T/tmpnmby18kh/tmp.obs.b8
#   0%|                                                                                                                                                                                                           | 0/52 [00:00<?, ?it/s]
#  35%|██████████████████████████████████████████████████████████████████▊                                                                                                                              | 18/52 [00:00<00:00, 175.18it/s]
#  69%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                           | 36/52 [00:00<00:00, 42.86it/s]
#  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                          | 45/52 [00:01<00:00, 27.61it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 51/52 [00:01<00:00, 23.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:01<00:00, 28.58it/s]
# (10, MultiDecoderLogicalErrorRates(results={'fb(max_tree_size=0)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0021150419997866265), 'fb(max_tree_size=1)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0017621250008232892), 'fb(max_tree_size=2)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.000206527777966888), 'fb(max_tree_size=3)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00018944333229834837), 'fb(max_tree_size=4)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00017588000143102062), 'fb(max_tree_size=5)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00014713000079306465), 'fb(max_tree_size=6)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0001483333310008877), 'fb(max_tree_size=7)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00017606444695654017), 'fb(max_tree_size=8)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0007217122199815802), 'fb(max_tree_size=9)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00014703777803030488), 'fb(max_tree_size=10)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0001888888841171542), 'fb(max_tree_size=15)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0018208330002380535), 'fb(max_tree_size=20)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00035879666635689017), 'fb(max_tree_size=25)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0017256249993806705), 'fb(max_tree_size=30)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0001309733326909029), 'fb(max_tree_size=35)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00011986111429804523), 'fb(max_tree_size=40)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00014300888627379513), 'fb(max_tree_size=45)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00015759221747026054), 'fb(max_tree_size=50)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=4.2129997584399665e-05), 'fb(max_tree_size=100)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00166654200074845), 'fb(max_tree_size=150)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0002138433329592873), 'fb(max_tree_size=200)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0001420377763376261), 'fb(max_tree_size=300)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00019222111505870192), 'fb(max_tree_size=500)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.000183055554872327), 'fb(max_tree_size=1000)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00015874999614122015), 'fb': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0004944911092429215), 'mwpf(c=0)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00032976777826358256), 'mwpf(c=1)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0001369444443197507), 'mwpf(c=2)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.000865092224557884), 'mwpf(c=3)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00016222111298702657), 'mwpf(c=4)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.00028032444081165723), 'mwpf(c=5)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0006938422262060663), 'mwpf(c=6)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0006322222220155203), 'mwpf(c=7)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0328380829996604), 'mwpf(c=8)': LogicalErrorResult(errors=0, discards=0, panic_cases=None, elapsed=0.0008879166651038557), 'mwpf(c=9)': LogicalErrorResult(errors=0, di ...

# %% [markdown]
# ### Define the strategy to submit jobs

# %%
precision_submitter = PrecisionSubmitter(
    time_limit=max_cpu_hours * 3600 if max_cpu_hours is not None else None,
    min_precision=None,
    target_precision=target_precision,
)

def submitter(executor: MonteCarloJobExecutor) -> list[tuple[MonteCarloJob, int]]:
    submit = precision_submitter(executor)
    return submit

# %% [markdown]
# ## The rest of the notebook runs the evaluation

# %%
config = MonteCarloExecutorConfig()
config.max_submitted_job = max(config.max_submitted_job, 3 * slurm_maximum_jobs)
executor = MonteCarloJobExecutor(
    monte_carlo_function,
    jobs,
    config=config,
    filename=json_filename,
    result_type=MultiDecoderLogicalErrorRates,
)

client_connector = SlurmClientConnector(
    slurm_maximum_jobs=slurm_maximum_jobs,
    slurm_cores_per_node=slurm_cores_per_node,
    slurm_mem_per_job=slurm_mem_per_job,
    slurm_extra=slurm_extra,
    local_maximum_jobs=local_maximum_jobs,
)

# %%
import time  # add some sleep to let them work properly in VScode Jupyter notebook

time.sleep(0.2)
progress_plotter = JobProgressPlotter()
time.sleep(0.2)
compare_decoder_plotter = CompareDecoderPlotter(
    decoders = decoders
)
time.sleep(0.2)
memory_plotter = MemoryUsagePlotter()


def callback(executor: MonteCarloJobExecutor):
    progress_plotter(executor)
    time.sleep(0.1)
    compare_decoder_plotter(executor)
    time.sleep(0.1)
    memory_plotter(executor)
    time.sleep(0.1)


executor.execute(
    client_connector=client_connector,
    submitter=submitter,
    loop_callback=callback,
    shutdown_cluster=True,
    force_finished=force_finished,
)
# Out:
# <style type="text/css">
# #T_3b1e0 th {
#   text-align: center;
# }
# #T_3b1e0_row0_col0, #T_3b1e0_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_3b1e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b1e0_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_3b1e0_level0_col1" class="col_heading level0 col1" >JobKey</th>
#       <th id="T_3b1e0_level0_col2" class="col_heading level0 col2" >Job</th>
#       <th id="T_3b1e0_level0_col3" class="col_heading level0 col3" >Finished</th>
#       <th id="T_3b1e0_level0_col4" class="col_heading level0 col4" >Pending</th>
#       <th id="T_3b1e0_level0_col5" class="col_heading level0 col5" >Submitted</th>
#       <th id="T_3b1e0_level0_col6" class="col_heading level0 col6" >1000 jobs</th>
#       <th id="T_3b1e0_level0_col7" class="col_heading level0 col7" >Total</th>
#       <th id="T_3b1e0_level0_col8" class="col_heading level0 col8" >Duration</th>
#       <th id="T_3b1e0_level0_col9" class="col_heading level0 col9" >Errors</th>
#       <th id="T_3b1e0_level0_col10" class="col_heading level0 col10" >Discards</th>
#       <th id="T_3b1e0_level0_col11" class="col_heading level0 col11" >Panics</th>
#       <th id="T_3b1e0_level0_col12" class="col_heading level0 col12" >Error Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b1e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b1e0_row0_col0" class="data row0 col0" >pending</td>
#       <td id="T_3b1e0_row0_col1" class="data row0 col1" >25b906</td>
#       <td id="T_3b1e0_row0_col2" class="data row0 col2" >Job(code=css_rsc(d=7), noise=depolarize(p=0.01))</td>
#       <td id="T_3b1e0_row0_col3" class="data row0 col3" >32084775 (2%)</td>
#       <td id="T_3b1e0_row0_col4" class="data row0 col4" >1283644703 (97%)</td>
#       <td id="T_3b1e0_row0_col5" class="data row0 col5" >170192452 (12%)</td>
#       <td id="T_3b1e0_row0_col6" class="data row0 col6" >1000 (100%)</td>
#       <td id="T_3b1e0_row0_col7" class="data row0 col7" >1315729478</td>
#       <td id="T_3b1e0_row0_col8" class="data row0 col8" >34275.5s (571.3min)</td>
#       <td id="T_3b1e0_row0_col9" class="data row0 col9" >108</td>
#       <td id="T_3b1e0_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_3b1e0_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_3b1e0_row0_col12" class="data row0 col12" >3.4(8)e-06</td>
#     </tr>
#   </tbody>
# </table>
# winding up a new client
# No module named 'dask_jobqueue'
# cluster dashboard link: http://127.0.0.1:8787/status
# 2025-06-10 14:58:49,416 - distributed.nanny - WARNING - Restarting worker
# 2025-06-10 14:58:49,417 - distributed.nanny - WARNING - Restarting worker
# 2025-06-10 14:58:49,430 - distributed.nanny - WARNING - Restarting worker
